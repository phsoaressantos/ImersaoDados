# %% [markdown]
# <a href="https://colab.research.google.com/github/phsoaressantos/ImersaoDados/blob/main/Imersao_dados_Alura.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url = "https://gist.githubusercontent.com/tgcsantos/3bdb29eba6ce391e90df2b72205ba891/raw/22fa920e80c9fa209a9fccc8b52d74cc95d1599b/dados_imoveis.csv"
dados = pd.read_csv(url)

# %%
dados.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor
# 0        4          8      6  R$ 7.000.000
# 1        4          4      4  R$ 3.700.000
# 2        4          3      2    R$ 380.000
# 3        3          2      4    R$ 685.000
# 4        3          2      2    R$ 540.000

# %%
dados.sample(10)
# Out:
#                               Rua                Bairro     Cidade  Metragem  \
# 5311  Rua Antônio Augusto Covello        Vila Monumento  São Paulo       200
# 5630                          NaN        Jardim Guedala  São Paulo       501
# 2265                  Rua Bolívia        Jardim América  São Paulo       420
# 3831              Rua Votuporanga                Sumaré  São Paulo       460
# 5341               Rua Pau Brasil               Boaçava  São Paulo       505
# 5143                          NaN  Chácara Monte Alegre  São Paulo       459
# 4442                    Rua Ipero  Jardim das Bandeiras  São Paulo       180
# 8778          Rua Jacques Blanche     Vila Buenos Aires  São Paulo       110
# 6833                          NaN            Campo Belo  São Paulo       215
# 6996              Rua José Varela            Interlagos  São Paulo       325
#
#       Quartos  Banheiros  Vagas         Valor
# 5311        3          3      2  R$ 1.300.000
# ...

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10008 entries, 0 to 10007
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Rua        6574 non-null   object
#  1   Bairro     9996 non-null   object
#  2   Cidade     10008 non-null  object
#  3   Metragem   10008 non-null  int64
#  4   Quartos    10008 non-null  int64
#  5   Banheiros  10008 non-null  int64
#  6   Vagas      10008 non-null  int64
#  7   Valor      10008 non-null  object
# dtypes: int64(4), object(4)
# memory usage: 625.6+ KB

# %%
dados["Bairro"][6522]
# Out:
# 'Vila Paulo Silas'

# %%
dados.Metragem.mean()
# Out:
# 442.30065947242207

# %%
dados["Metragem"].mean()
# Out:
# 442.30065947242207

# %%
sum((dados["Bairro"] == "Vila Mariana"))
# Out:
# 184

# %%
tem_imoveis_vila =( dados["Bairro"] == "Vila Mariana")
tem_imoveis_vila
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10003    False
# 10004    False
# 10005    False
# 10006    False
# 10007    False
# Name: Bairro, Length: 10008, dtype: bool

# %%
imoveis_vila_mariana = dados[tem_imoveis_vila]
imoveis_vila_mariana
# Out:
#                                Rua        Bairro     Cidade  Metragem  \
# 100               Rua Pero Correia  Vila Mariana  São Paulo       250
# 120   Praça Doutor Carvalho Franco  Vila Mariana  São Paulo       250
# 155     Rua Professor João Marinho  Vila Mariana  São Paulo       170
# 160                            NaN  Vila Mariana  São Paulo       228
# 334         Rua Pero Correia, 892   Vila Mariana  São Paulo       350
# ...                            ...           ...        ...       ...
# 9645               Rua Sousa Ramos  Vila Mariana  São Paulo       285
# 9701             Rua Benito Juarez  Vila Mariana  São Paulo       171
# 9737             Rua Benito Juarez  Vila Mariana  São Paulo       171
# 9807                           NaN  Vila Mariana  São Paulo       275
# 9852              Rua França Pinto  Vila Mariana  São Paulo       280
#
#       Quartos  Banheiros  Vagas         Valor
# 100         3          3      1  R$ 1.350.000
# ...

# %%
imoveis_vila_mariana["Metragem"].mean()
# Out:
# 233.6195652173913

# %%
dados["Bairro"].value_counts()
# Out:
# Alto de Pinheiros     409
# Jardim Guedala        403
# Jardim Paulista       309
# Brooklin Paulista     247
# Jardim Europa         240
#                      ...
# Jardim das Imbuias      1
# Vila Represa            1
# Vila Nancy              1
# Sítio Represa           1
# Vila Invernada          1
# Name: Bairro, Length: 701, dtype: int64

# %%
n_imoveis_bairro = dados["Bairro"].value_counts()
n_imoveis_bairro.head(10).plot.bar()

# %% [markdown]
# Desafios:
#
# 1 - Realizar a média da metragem para cara um dos bairros (Paulo)
#
# 2 - 2 formas de selecionar os dados por bairro (consultar os métodos na documentação do pandas) (Thiago)
#
# 3 - Explorar alguns gráficos na documentação e aplicar nas demais colunas do DF, tentar colocar alguma conclusão (Thiago)
#
# 4 - Pegar outros estatísticas dos dados, média, mediana, mim, max (Vivi)
#
# 5 - Descobrir quais são os bairros que não tem nome de Rua. (Vivi)

# %%
# média geral

dados["Metragem"].mean()
# Out:
# 442.30065947242207

# %%
from numpy.ma.core import count
n_imoveis_pacaembu =sum((dados["Bairro"] == "Pacaembu"))
n_imoveis_pacaembu
# Out:
# 222

# %%
imoveis_pacaembu = dados[tem_imoveis_pacaembu]
imoveis_pacaembu
# Out:
#                                        Rua    Bairro     Cidade  Metragem  \
# 267                                    NaN  Pacaembu  São Paulo       306
# 293    Rua José de Freitas Guimarães, 353   Pacaembu  São Paulo       400
# 297              Rua Cássio Martins Vilaça  Pacaembu  São Paulo       288
# 346                                    NaN  Pacaembu  São Paulo       390
# 350                Praça Sílvio de Almeida  Pacaembu  São Paulo       550
# ...                                    ...       ...        ...       ...
# 9928                             Rua Bauru  Pacaembu  São Paulo       434
# 9954                          Rua Bragança  Pacaembu  São Paulo       285
# 9964                             Rua Bauru  Pacaembu  São Paulo       439
# 9990                          Rua Bragança  Pacaembu  São Paulo       285
# 10000                            Rua Bauru  Pacaembu  São Paulo       439
#
#        Quartos  Banheiros  Vagas                                  Valor
# ...

# %%
soma_metragem_pacaembu = sum((imoveis_pacaembu["Metragem"]))
soma_metragem_pacaembu
# Out:
# 113843

# %%
media_pacaembu = soma_metragem_pacaembu / n_imoveis_pacaembu
media_pacaembu
# Out:
# 512.8063063063063

# %%
df["Bairro"].unique()
# Out:
# Bairro
# Aclimação                    [Aclimação]
# Alto da Boa Vista    [Alto da Boa Vista]
# Alto da Lapa              [Alto da Lapa]
# Alto da Mooca            [Alto da Mooca]
# Alto de Pinheiros    [Alto de Pinheiros]
#                             ...
# Vila Água Funda        [Vila Água Funda]
# Água Branca                [Água Branca]
# Água Fria                    [Água Fria]
# Água Funda                  [Água Funda]
# Água Rasa                    [Água Rasa]
# Name: Bairro, Length: 701, dtype: object

# %%
df.Metragem.head()
# Out:
# 0        1000
# 1         496
# 2         125
# 3         310
# 4         100
#          ...
# 9981      245
# 9989      127
# 9992       80
# 9996      101
# 10003      95
# Name: Metragem, Length: 2243, dtype: int64

# %%
from numpy.core.fromnumeric import mean
# Calculando Media de todos os bairros
df_medias = dados.groupby(["Bairro"], as_index=False)["Metragem"].mean()
df_medias
# Out:
#                 Bairro    Metragem
# 0            Aclimação  253.056818
# 1    Alto da Boa Vista  418.875000
# 2         Alto da Lapa  294.337209
# 3        Alto da Mooca  270.050000
# 4    Alto de Pinheiros  433.444988
# ..                 ...         ...
# 696    Vila Água Funda  152.200000
# 697        Água Branca  191.000000
# 698          Água Fria  165.416667
# 699         Água Funda  139.000000
# 700          Água Rasa  340.250000
#
# [701 rows x 2 columns]

# %%
dados.describe()
# Out:
#             Metragem       Quartos     Banheiros         Vagas
# count   10008.000000  10008.000000  10008.000000  10008.000000
# mean      442.300659      3.483114      3.879097      4.097222
# std      7515.379389      1.064200      1.988467      2.824014
# min        10.000000      1.000000      1.000000      1.000000
# 25%       173.000000      3.000000      2.000000      2.000000
# 50%       290.000000      3.000000      4.000000      4.000000
# 75%       460.250000      4.000000      5.000000      5.000000
# max    750000.000000     16.000000     40.000000     50.000000

# %%
# dados por bairro com GroupBy
df_valores = dados.groupby(["Bairro"], as_index=False).mean()
df_valores
# Out:
#                 Bairro    Metragem   Quartos  Banheiros     Vagas
# 0            Aclimação  253.056818  3.318182   3.079545  2.909091
# 1    Alto da Boa Vista  418.875000  4.125000   5.125000  4.625000
# 2         Alto da Lapa  294.337209  3.151163   3.790698  3.906977
# 3        Alto da Mooca  270.050000  3.300000   2.600000  3.650000
# 4    Alto de Pinheiros  433.444988  3.938875   4.838631  5.004890
# ..                 ...         ...       ...        ...       ...
# 696    Vila Água Funda  152.200000  2.600000   2.200000  2.600000
# 697        Água Branca  191.000000  3.153846   3.076923  2.461538
# 698          Água Fria  165.416667  2.833333   3.416667  2.500000
# 699         Água Funda  139.000000  3.000000   2.500000  2.000000
# 700          Água Rasa  340.250000  3.500000   3.250000  5.250000
#
# [701 rows x 5 columns]

# %%
# Rua Vazia
# tem_imoveis_vila =( dados["Rua"] == "Vila Mariana")
rua_vazia = (dados["Rua"] == '')
rua_vazia
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10003    False
# 10004    False
# 10005    False
# 10006    False
# 10007    False
# Name: Rua, Length: 10008, dtype: bool

# %%
df_valores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 701 entries, 0 to 700
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Bairro     701 non-null    object
#  1   Metragem   701 non-null    float64
#  2   Quartos    701 non-null    float64
#  3   Banheiros  701 non-null    float64
#  4   Vagas      701 non-null    float64
# dtypes: float64(4), object(1)
# memory usage: 27.5+ KB

# %%
df_ruas = dados.groupby(["Rua"], as_index=False).count()
df_ruas
# Out:
#                               Rua  Bairro  Cidade  Metragem  Quartos  \
# 0                 Alameda Calicut       1       1         1        1
# 1                Alameda Campinas       1       1         1        1
# 2                  Alameda Canuri       2       2         2        2
# 3             Alameda Casa Branca       1       1         1        1
# 4                  Alameda Franca       4       4         4        4
# ...                           ...     ...     ...       ...      ...
# 3125  Travessa Saveiros de Maroim       2       2         2        2
# 3126    Travessa Umberto Bignardi       2       2         2        2
# 3127                     Viela Um       4       4         4        4
# 3128              Viela Um, 1059        1       1         1        1
# 3129               Viela Um, 289        2       2         2        2
#
#       Banheiros  Vagas  Valor
# 0             1      1      1
# 1             1      1      1
# 2             2      2      2
# ...

# %%
df_ruas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3130 entries, 0 to 3129
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Rua        3130 non-null   object
#  1   Metragem   3130 non-null   float64
#  2   Quartos    3130 non-null   float64
#  3   Banheiros  3130 non-null   float64
#  4   Vagas      3130 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 122.4+ KB

# %%
# Numero de ruas vazias

dados["Rua"].isnull().sum()
# Out:
# 3434
